# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
resumes = [
    "Python Java SQL Machine Learning",
    "HTML CSS JavaScript React",
    "Python Pandas Data Analysis Excel",
    "Java Spring Boot MySQL"
]

candidates = [
    "Candidate A",
    "Candidate B",
    "Candidate C",
    "Candidate D"
]
job_description = "Python Machine Learning SQL"
documents = [job_description] + resumes
vectorizer = CountVectorizer()
matrix = vectorizer.fit_transform(documents)
similarity = cosine_similarity(matrix[0:1], matrix[1:])
scores = similarity[0]
print(scores)
results = pd.DataFrame({
    "Candidate": candidates,
    "Match Score": scores
})
results = results.sort_values(
    by="Match Score",
    ascending=False
)
print(results)
# Out:
# [0.89442719 0.         0.2236068  0.        ]
#      Candidate  Match Score
# 0  Candidate A     0.894427
# 2  Candidate C     0.223607
# 1  Candidate B     0.000000
# 3  Candidate D     0.000000
